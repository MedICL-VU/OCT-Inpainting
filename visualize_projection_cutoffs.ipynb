# %%
# import os
# import numpy as np
# import tifffile as tiff
# import matplotlib.pyplot as plt

# # Paths
# oct_projection_dir = "/media/admin/Expansion/Mosaic_Data_for_Ipeks_Group/OCT Projections/"
# oct_cutoff_dir = "/media/admin/Expansion/Mosaic_Data_for_Ipeks_Group/OCT_VolumeSplit_Indices/"

# # Match projection and cutoff files by common prefix
# projections = [f for f in os.listdir(oct_projection_dir) if f.endswith("_OCTavgProj.tif")]

# for proj_file in sorted(projections):
#     base_name = proj_file.replace("_OCTavgProj.tif", "")
#     cutoff_file = f"{base_name}_OCT_Cutoff_Indices.txt"

#     proj_path = os.path.join(oct_projection_dir, proj_file)
#     cutoff_path = os.path.join(oct_cutoff_dir, cutoff_file)

#     if not os.path.exists(cutoff_path):
#         print(f"Missing cutoff file for {proj_file}")
#         continue

#     # Load projection
#     projection = tiff.imread(proj_path)
#     if projection.ndim == 3:
#         projection = projection[0]  # If extra dim

#     # Load cutoff indices
#     with open(cutoff_path, "r") as f:
#         cutoff_indices = [int(line.strip()) for line in f if line.strip().isdigit()]

#     # Plot
#     plt.figure(figsize=(12, 4))
#     plt.imshow(projection, cmap='gray', aspect='auto')
#     for cutoff in cutoff_indices:
#         plt.axvline(x=cutoff, color='red', linestyle='--')
#     plt.title(f"{proj_file} with cutoffs")
#     plt.xlabel("A-scan index")
#     plt.ylabel("Depth")
#     plt.tight_layout()
#     plt.show()
